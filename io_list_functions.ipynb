# %% [markdown]
# <a href="https://colab.research.google.com/github/SougataJoy/IO-List-Creation/blob/main/io_list_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cell 1 — MUST run this first
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.makedirs('/content/drive/MyDrive/Python/Colab/IO_List_Project/', exist_ok=True)
print('✅ Folder created.')
# Out:
# ✅ Folder created.

# %%
# %%writefile /content/drive/MyDrive/Python/Colab/IO_List_Project/styles.py
# ================  Function-001  ================
# ================  styles.py  ================
# All visual constants: borders, fills, fonts, alignments.
# No imports from other project files — this is the base layer.
# Every other module will import from here.

from openpyxl.styles import Font, Alignment, PatternFill, Border, Side

# ---- Border sides ----
THIN  = Side(style='thin')
THICK = Side(style='thick')

# ---- Cell fills ----
YELLOW_FILL = PatternFill(start_color="FFFF00", fill_type="solid")
ORANGE_FILL = PatternFill(start_color="FFC000", fill_type="solid")

# ---- Fonts ----
TNR_26B = Font(name='Times New Roman', size=26, bold=True)
TNR_9B  = Font(name='Times New Roman', size=9,  bold=True)
CAL_18B = Font(name='Calibri', size=18, bold=True)
CAL_16B = Font(name='Calibri', size=16, bold=True)
CAL_16  = Font(name='Calibri', size=16, bold=False)

# ---- Alignments ----
CENTER   = Alignment(horizontal='center', vertical='center', wrap_text=True)
CENTER_H = Alignment(horizontal='center', wrap_text=True)
RIGHT    = Alignment(horizontal='right',  wrap_text=True)
LEFT     = Alignment(horizontal='left',   wrap_text=True)
# Out:
# Writing /content/drive/MyDrive/Python/Colab/IO_List_Project/styles.py
